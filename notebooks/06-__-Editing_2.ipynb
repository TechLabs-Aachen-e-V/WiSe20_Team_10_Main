# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../Data/Editing.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19679 entries, 0 to 19678
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   server         19679 non-null  object
#  1   summoner_name  19679 non-null  object
#  2   winner         19679 non-null  object
#  3   BTop           19679 non-null  object
#  4   BJng           19679 non-null  object
#  5   BMid           19679 non-null  object
#  6   BAdc           19679 non-null  object
#  7   BSup           19679 non-null  object
#  8   RTop           19679 non-null  object
#  9   RJng           19679 non-null  object
#  10  RMid           19679 non-null  object
#  11  RAdc           19679 non-null  object
#  12  RSup           19679 non-null  object
#  13  Time           19679 non-null  object
# dtypes: object(14)
# memory usage: 2.1+ MB

# %%
df
# Out:
#       server summoner_name  winner      BTop            BJng          BMid  \
# 0         na          AnDa  Team 2   Camille          Gragas          Yone
# 1         na          AnDa  Team 1   Camille         Nidalee         Galio
# 2         na          AnDa  Team 1    Irelia            Ekko         Annie
# 3         na          AnDa  Team 2    Graves         Kindred         Sylas
# 4         na          AnDa  Team 2   Camille         Lee Sin        Lucian
# 5         na          AnDa  Team 1   Camille         Nidalee         Jayce
# 6         na          AnDa  Team 2   Camille        Cho'Gath      Vladimir
# 7         na          AnDa  Team 2  Vladimir         Kindred          Lulu
# 8         na          AnDa  Team 2  Volibear    Fiddlesticks         Galio
# 9         na         Yeon7  Team 1  Renekton            Olaf  Twisted Fate
# 10        na         Yeon7  Team 1     Riven          Lillia         Sylas
# ...

# %%
df['Winner'] = df['winner']

# %%
for i in range(19679):
    if(df['Winner'][i]=='Team 1'):
        df['winner'][i] = 'Blue'
    else:
        df['winner'][i] = 'Red'

# %%
df.drop('Winner',axis=1,inplace=True)

# %%
df.to_csv('LOLOracleData.csv',index=False)
