# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('games.csv',header='infer')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 670 entries, 0 to 669
# Data columns (total 7 columns):
# duration         670 non-null object
# result           670 non-null object
# server           670 non-null object
# summoner_name    670 non-null object
# team_1           670 non-null object
# team_2           670 non-null object
# timestamp        670 non-null object
# dtypes: object(7)
# memory usage: 36.7+ KB

# %%
df['summoner_name'].nunique()
# Out:
# 84

# %%
df
# Out:
#     duration       result server     summoner_name  \
# 0    28m 29s  Team 1 Wins    euw     Shending Help
# 1     32m 5s  Team 2 Wins    euw     Shending Help
# 2    26m 35s  Team 2 Wins    euw     Shending Help
# 3     22m 2s  Team 1 Wins    euw     Shending Help
# 4    20m 12s  Team 1 Wins    euw     Shending Help
# 5    31m 31s  Team 1 Wins    euw     UjebaneNogiTV
# 6    23m 53s  Team 2 Wins    euw     UjebaneNogiTV
# 7    22m 38s  Team 2 Wins    euw      Marius Aymar
# 8    26m 24s  Team 2 Wins    euw    Last Sacrifice
# 9    24m 38s  Team 1 Wins    euw      Marius Aymar
# 10   20m 52s  Team 2 Wins    euw    Last Sacrifice
# 11   28m 56s  Team 2 Wins    euw    Last Sacrifice
# 12   34m 17s  Team 2 Wins    euw      Marius Aymar
# 13   25m 50s  Team 1 Wins    euw       DuaIistdusk
# 14   29m 54s  Team 1 Wins    euw    Last Sacrifice
# 15   32m 37s  Team 2 Wins    euw    Last Sacrifice
# 16   19m 43s  Team 2 Wins    euw      Marius Aymar
# ...

# %%
team_1: ['Darius', 'Lillia', 'Talon', 'Miss Fortune', 'Alistar'],
team_2: ['Camille', 'Ivern', 'Vladimir', "Kai'Sa", 'Leona']
# Out:
#   File "<ipython-input-1-0a3a13de3e57>", line 1
#     team_1: ['Darius', 'Lillia', 'Talon', 'Miss Fortune', 'Alistar'],
#                                                                     ^
# SyntaxError: invalid syntax

# %%
Red['Top'] = team_2[0]
Red['Jng'] = team_2[1]
Red['Mid'] = team_2[2]
Red['ADC'] = team_2[3]
Red['Sup'] = team_2[4]

Blue['Top'] = team_1[0]
Blue['Jng'] = team_1[1]
Blue['Mid'] = team_1[2]
Blue['ADC'] = team_1[3]
Blue['Sup'] = team_1[4]
