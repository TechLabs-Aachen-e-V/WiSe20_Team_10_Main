# %% [markdown]
# # To determine the classification of Game results using Decision trees & Random Forests

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../../data/processed/LOLOracleData_ChampStats.csv')

# %%
df.head()
# Out:
#       BTop    BTopWr    BToptags  BTophp  BTophpperlevel  BTopmovespeed  \
# 0  Camille  0.524364       Diver   575.6              85            340
# 1  Camille  0.524364       Diver   575.6              85            340
# 2   Irelia  0.513399       Diver   580.0              95            335
# 3   Graves  0.511305  Specialist   555.0              92            340
# 4  Camille  0.524364       Diver   575.6              85            340
#
#    BToparmor  BToparmorperlevel  BTopspellblock  BTopspellblockperlevel  ...  \
# 0       35.0                3.8            32.1                    1.25  ...
# 1       35.0                3.8            32.1                    1.25  ...
# 2       36.0                3.0            32.0                    1.25  ...
# 3       33.0                3.4            32.0                    1.25  ...
# 4       35.0                3.8            32.1                    1.25  ...
#
#    RSupspellblock  RSupspellblockperlevel  RSupattackrange  RSuphpregen  \
# 0            30.0                    0.50              525          5.5
# 1            30.0                    0.50              525          5.5
# 2            32.1                    1.25              125          5.0
# 3            32.0                    1.25              150          7.0
# 4            28.0                    1.25              175         10.0
#
#    RSuphpregenperlevel  RSupattackdamage  RSupattackdamageperlevel  \
# 0                 0.55           53.5440                    3.3000
# 1                 0.55           54.9379                    3.1416
# 2                 0.75           63.5400                    3.3000
# 3                 0.50           62.0000                    2.0000
# 4                 0.65           64.0000                    3.3000
#
#   RSupattackspeedperlevel  RSupattackspeed Winner
# 0                   2.300            0.625      1
# 1                   1.360            0.625      0
# 2                   2.125            0.800      0
# 3                   2.500            0.667      1
# 4                   2.950            0.644      1
#
# [5 rows x 171 columns]

# %%
print(df.columns)
# Out:
# Index(['BTop', 'BTopWr', 'BToptags', 'BTophp', 'BTophpperlevel',
#        'BTopmovespeed', 'BToparmor', 'BToparmorperlevel', 'BTopspellblock',
#        'BTopspellblockperlevel',
#        ...
#        'RSupspellblock', 'RSupspellblockperlevel', 'RSupattackrange',
#        'RSuphpregen', 'RSuphpregenperlevel', 'RSupattackdamage',
#        'RSupattackdamageperlevel', 'RSupattackspeedperlevel',
#        'RSupattackspeed', 'Winner'],
#       dtype='object', length=171)

# %%
req_cols = ['BTop','BJng','BMid','BAdc','BSup','RTop','RJng','RMid','RAdc','RSup','BTopWr','BJngWr','BMidWr','BAdcWr','BSupWr','RTopWr','RJngWr','RMidWr','RAdcWr','RSupWr','BToptags','BJngtags','BMidtags','BAdctags','BSuptags','RToptags','RJngtags','RMidtags','RAdctags','RSuptags','Winner']

# %%
columns = list(df.columns)

# %%
for i in range(len(req_cols)):
    columns.remove(req_cols[i])

# %%
columns
# Out:
# ['BTophp',
#  'BTophpperlevel',
#  'BTopmovespeed',
#  'BToparmor',
#  'BToparmorperlevel',
#  'BTopspellblock',
#  'BTopspellblockperlevel',
#  'BTopattackrange',
#  'BTophpregen',
#  'BTophpregenperlevel',
#  'BTopattackdamage',
#  'BTopattackdamageperlevel',
#  'BTopattackspeedperlevel',
#  'BTopattackspeed',
#  'BJnghp',
#  'BJnghpperlevel',
#  'BJngmovespeed',
#  'BJngarmor',
#  'BJngarmorperlevel',
#  'BJngspellblock',
#  'BJngspellblockperlevel',
#  'BJngattackrange',
#  'BJnghpregen',
#  'BJnghpregenperlevel',
#  'BJngattackdamage',
#  'BJngattackdamageperlevel',
#  'BJngattackspeedperlevel',
#  'BJngattackspeed',
#  'BMidhp',
#  'BMidhpperlevel',
#  'BMidmovespeed',
#  'BMidarmor',
#  'BMidarmorperlevel',
#  'BMidspellblock',
#  'BMidspellblockperlevel',
#  'BMidattackrange',
#  'BMidhpregen',
#  'BMidhpregenperlevel',
#  'BMidattackdamage',
#  'BMidattackdamageperlevel',
#  'BMidattackspeedperlevel',
#  'BMidattackspeed',
#  'BAdchp',
#  'BAdchpperlevel',
#  'BAdcmovespeed',
#  'BAdcarmor',
#  'BAdcarmorperlevel',
#  'BAdcspellblock',
#  'BAdcspellblockperlevel',
#  'BAdcattackrange',
#  'BAdchpregen',
#  'BAdchpregenperlevel',
#  'BAdcattackdamage',
#  'BAdcattackdamageperlevel',
#  'BAdcattackspeedperlevel',
#  'BAdcattackspeed',
#  'BSuphp',
#  'BSuphpperlevel',
#  'BSupmovespeed',
#  'BSuparmor',
#  'BSuparmorperlevel',
#  'BSupspellblock',
#  'BSupspellblockperlevel',
#  'BSupattackrange',
#  'BSuphpregen',
#  'BSuphpregenperlevel',
#  'BSupattackdamage',
#  'BSupattackdamageperlevel',
#  'BSupattackspeedperlevel',
#  'BSupattackspeed',
#  'RTophp',
#  'RTophpperlevel',
#  'RTopmovespeed',
#  'RToparmor',
#  'RToparmorperlevel',
#  'RTopspellblock',
#  'RTopspellblockperlevel',
#  'RTopattackrange',
#  'RTophpregen',
#  'RTophpregenperlevel',
#  'RTopattackdamage',
#  'RTopattackdamageperlevel',
#  'RTopattackspeedperlevel',
#  'RTopattackspeed',
#  'RJnghp',
#  'RJnghpperlevel',
#  'RJngmovespeed',
#  'RJngarmor',
#  'RJngarmorperlevel',
#  'RJngspellblock',
#  'RJngspellblockperlevel',
#  'RJngattackrange',
#  'RJnghpregen',
#  'RJnghpregenperlevel',
#  'RJngattackdamage',
#  'RJngattackdamageperlevel',
#  'RJngattackspeedperlevel',
#  'RJngattackspeed',
#  'RMidhp',
#  'RMidhpperlevel',
#  'RMidmovespeed',
#  'RMidarmor',
#  'RMidarmorperlevel',
#  'RMidspellblock',
#  'RMidspellblockperlevel',
#  'RMidattackrange',
#  'RMidhpregen',
#  'RMidhpregenperlevel',
#  'RMidattackdamage',
#  'RMidattackdamageperlevel',
#  'RMidattackspeedperlevel',
#  'RMidattackspeed',
#  'RAdchp',
#  'RAdchpperlevel',
#  'RAdcmovespeed',
#  'RAdcarmor',
#  'RAdcarmorperlevel',
#  'RAdcspellblock',
#  'RAdcspellblockperlevel',
#  'RAdcattackrange',
#  'RAdchpregen',
#  'RAdchpregenperlevel',
#  'RAdcattackdamage',
#  'RAdcattackdamageperlevel',
#  'RAdcattackspeedperlevel',
#  'RAdcattackspeed',
#  'RSuphp',
#  'RSuphpperlevel',
#  'RSupmovespeed',
#  'RSuparmor',
#  'RSuparmorperlevel',
#  'RSupspellblock',
#  'RSupspellblockperlevel',
#  'RSupattackrange',
#  'RSuphpregen',
#  'RSuphpregenperlevel',
#  'RSupattackdamage',
#  'RSupattackdamageperlevel',
#  'RSupattackspeedperlevel',
#  'RSupattackspeed']

# %%
df.drop(columns,axis=1,inplace=True)

# %%
df
# Out:
#            BTop    BTopWr    BToptags     BJng    BJngWr    BJngtags  \
# 0       Camille  0.524364       Diver   Gragas  0.506967    Vanguard
# 1       Camille  0.524364       Diver  Nidalee  0.504318  Specialist
# 2        Irelia  0.513399       Diver     Ekko  0.486450    Assassin
# 3        Graves  0.511305  Specialist  Kindred  0.505097    Marksman
# 4       Camille  0.524364       Diver  Lee Sin  0.509764       Diver
# ...         ...       ...         ...      ...       ...         ...
# 19674     Jayce  0.517039   Artillery   Graves  0.511305  Specialist
# 19675    Lucian  0.471641    Marksman   Lillia  0.504717  Skirmisher
# 19676  Tristana  0.493113    Marksman   Graves  0.511305  Specialist
# 19677  Vladimir  0.470149  Battlemage     Udyr  0.507246  Juggernaut
# 19678   Camille  0.524364       Diver  Lee Sin  0.509764       Diver
#
#                BMid    BMidWr    BMidtags    BAdc  ...     RMid    RMidWr  \
# 0              Yone  0.497972  Skirmisher    Jhin  ...    Sylas  0.491465
# 1             Galio  0.565594      Warden    Jhin  ...   Xerath  0.559211
# 2             Annie  0.553073       Burst  Kai'Sa  ...  Orianna  0.465315
# 3             Sylas  0.502868       Burst   Vayne  ...     Ekko  0.508434
# 4            Lucian  0.421169    Marksman  Kai'Sa  ...     Yone  0.445918
# ...             ...       ...         ...     ...  ...      ...       ...
# 19674        Viktor  0.517730  Battlemage   Swain  ...    Galio  0.551313
# 19675          Ekko  0.533333    Assassin   Vayne  ...     Azir  0.532787
# 19676        Wukong  0.521495       Diver   Ziggs  ...   Lucian  0.467672
# 19677  Twisted Fate  0.470037       Burst  Samira  ...   Viktor  0.506708
# 19678         Sylas  0.502868       Burst  Ezreal  ...    Galio  0.551313
#
#          RMidtags          RAdc    RAdcWr  RAdctags       RSup    RSupWr  \
# 0           Burst        Kai'Sa  0.503883  Marksman      Karma  0.492260
# 1       Artillery  Miss Fortune  0.504505  Marksman    Vel'Koz  0.440678
# 2           Burst      Aphelios  0.470158  Marksman     Maokai  0.527418
# 3        Assassin         Sivir  0.393443  Marksman       Pyke  0.492582
# 4      Skirmisher       Orianna  0.465315     Burst   Pantheon  0.473513
# ...           ...           ...       ...       ...        ...       ...
# 19674      Warden        Ezreal  0.457083  Marksman  Seraphine  0.487002
# 19675  Specialist        Samira  0.476318  Marksman    Alistar  0.509198
# 19676    Marksman        Ezreal  0.457083  Marksman      Braum  0.479401
# 19677  Battlemage        Lucian  0.497414  Marksman     Thresh  0.516721
# 19678      Warden        Kai'Sa  0.503883  Marksman      Rakan  0.484816
#
#         RSuptags  Winner
# 0      Enchanter       1
# 1      Artillery       0
# 2       Vanguard       0
# 3       Assassin       1
# 4          Diver       1
# ...          ...     ...
# 19674  Enchanter       1
# 19675   Vanguard       1
# 19676     Warden       0
# 19677    Catcher       0
# 19678    Catcher       1
#
# [19679 rows x 31 columns]

# %%
df2 = pd.read_csv('../../data/processed/LOLOracleDatawithSynscores.csv')

# %%
df2.head()
# Out:
#       BTop     BJng    BMid    BAdc    BSup      RTop       RJng     RMid  \
# 0  Camille   Gragas    Yone    Jhin   Brand      Shen     Graves    Sylas
# 1  Camille  Nidalee   Galio    Jhin  Anivia     Riven    Hecarim   Xerath
# 2   Irelia     Ekko   Annie  Kai'Sa  Thresh    Aatrox  Jarvan IV  Orianna
# 3   Graves  Kindred   Sylas   Vayne    Bard  Renekton    Nidalee     Ekko
# 4  Camille  Lee Sin  Lucian  Kai'Sa   Leona      Jhin    Nidalee     Yone
#
#            RAdc      RSup  Winner  BSyn  RSyn
# 0        Kai'Sa     Karma       1   136   282
# 1  Miss Fortune   Vel'Koz       0   496    66
# 2      Aphelios    Maokai       0   236    16
# 3         Sivir      Pyke       1    60   104
# 4       Orianna  Pantheon       1   -32   -32

# %%
df2.columns
# Out:
# Index(['BTop', 'BJng', 'BMid', 'BAdc', 'BSup', 'RTop', 'RJng', 'RMid', 'RAdc',
#        'RSup', 'Winner', 'BSyn', 'RSyn'],
#       dtype='object')

# %%
df2.drop(['BTop', 'BJng', 'BMid', 'BAdc', 'BSup', 'RTop', 'RJng', 'RMid', 'RAdc',
       'RSup', 'Winner'],axis=1,inplace=True)

# %%
df = pd.concat([df,df2],axis=1)

# %%
df.head(50)
# Out:
#            BTop    BTopWr    BToptags            BJng    BJngWr    BJngtags  \
# 0       Camille  0.524364       Diver          Gragas  0.506967    Vanguard
# 1       Camille  0.524364       Diver         Nidalee  0.504318  Specialist
# 2        Irelia  0.513399       Diver            Ekko  0.486450    Assassin
# 3        Graves  0.511305  Specialist         Kindred  0.505097    Marksman
# 4       Camille  0.524364       Diver         Lee Sin  0.509764       Diver
# 5       Camille  0.524364       Diver         Nidalee  0.504318  Specialist
# 6       Camille  0.524364       Diver        Cho'Gath  0.458904  Specialist
# 7      Vladimir  0.470149  Battlemage         Kindred  0.505097    Marksman
# 8      Volibear  0.448718  Juggernaut    Fiddlesticks  0.557018  Specialist
# 9      Renekton  0.507547       Diver            Olaf  0.548387       Diver
# 10        Riven  0.515086  Skirmisher          Lillia  0.504717  Skirmisher
# 11       Aatrox  0.542403  Juggernaut            Ekko  0.486450    Assassin
# 12       Wukong  0.521495       Diver         Kindred  0.505097    Marksman
# 13         Sett  0.498824  Juggernaut          Graves  0.511305  Specialist
# 14       Wukong  0.521495       Diver         Hecarim  0.518156       Diver
# 15        Sylas  0.477273       Burst          Rengar  0.474320    Assassin
# 16      Camille  0.524364       Diver           Poppy  0.451613      Warden
# 17         Shen  0.529830      Warden            Olaf  0.548387       Diver
# 18      Camille  0.524364       Diver         Nidalee  0.504318  Specialist
# 19         Sett  0.498824  Juggernaut         Evelynn  0.449383    Assassin
# 20         Lulu  0.559524   Enchanter          Graves  0.511305  Specialist
# 21       Kennen  0.538462  Specialist          Graves  0.511305  Specialist
# 22      Camille  0.524364       Diver       Dr. Mundo  0.417582  Juggernaut
# 23         Shen  0.529830      Warden          Lillia  0.504717  Skirmisher
# 24       Wukong  0.521495       Diver    Fiddlesticks  0.557018  Specialist
# 25        Akali  0.469274    Assassin            Olaf  0.548387       Diver
# 26        Sylas  0.477273       Burst          Graves  0.511305  Specialist
# 27     Renekton  0.507547       Diver            Ekko  0.486450    Assassin
# 28        Urgot  0.464286  Juggernaut  Nunu & Willump  0.518519    Vanguard
# 29       Wukong  0.521495       Diver          Graves  0.511305  Specialist
# 30     Vladimir  0.470149  Battlemage          Graves  0.511305  Specialist
# 31      Hecarim  0.518156       Diver         Kindred  0.505097    Marksman
# 32        Annie  0.531561       Burst            Kayn  0.507863  Skirmisher
# 33       Aatrox  0.542403  Juggernaut           Ivern  0.527473     Catcher
# 34         Sion  0.470588    Vanguard          Rengar  0.474320    Assassin
# 35        Jayce  0.517039   Artillery          Lillia  0.504717  Skirmisher
# 36         Ornn  0.480663    Vanguard            Kayn  0.507863  Skirmisher
# 37     Malphite  0.500566    Vanguard           Elise  0.497863       Diver
# 38     Malphite  0.500566    Vanguard           Shaco  0.440415    Assassin
# 39         Ornn  0.480663    Vanguard          Graves  0.511305  Specialist
# 40         Shen  0.529830      Warden         Hecarim  0.518156       Diver
# 41   Tryndamere  0.476636  Skirmisher            Kayn  0.507863  Skirmisher
# 42         Shen  0.529830      Warden            Kayn  0.507863  Skirmisher
# 43         Pyke  0.468790    Assassin    Fiddlesticks  0.557018  Specialist
# 44        Fiora  0.501906  Skirmisher            Kayn  0.507863  Skirmisher
# 45      Camille  0.524364       Diver            Ekko  0.486450    Assassin
# 46       Lucian  0.471641    Marksman         Nidalee  0.504318  Specialist
# 47      Camille  0.524364       Diver        Pantheon  0.511370       Diver
# 48         Yone  0.464567  Skirmisher             Zac  0.443850    Vanguard
# 49  Mordekaiser  0.466667  Juggernaut            Olaf  0.548387       Diver
#
#             BMid    BMidWr    BMidtags          BAdc  ...    RMidtags  \
# 0           Yone  0.497972  Skirmisher          Jhin  ...       Burst
# 1          Galio  0.565594      Warden          Jhin  ...   Artillery
# 2          Annie  0.553073       Burst        Kai'Sa  ...       Burst
# 3          Sylas  0.502868       Burst         Vayne  ...    Assassin
# 4         Lucian  0.421169    Marksman        Kai'Sa  ...  Skirmisher
# 5          Jayce  0.511962   Artillery        Kai'Sa  ...    Marksman
# 6       Vladimir  0.520958  Battlemage          Jhin  ...    Assassin
# 7           Lulu  0.498881   Enchanter    Tahm Kench  ...  Battlemage
# 8          Galio  0.565594      Warden        Ezreal  ...    Assassin
# 9   Twisted Fate  0.470037       Burst     Seraphine  ...    Vanguard
# 10         Sylas  0.502868       Burst        Ezreal  ...    Assassin
# 11          Azir  0.496815  Specialist         Neeko  ...  Battlemage
# 12         Sylas  0.502868       Burst          Ashe  ...    Assassin
# 13        Viktor  0.517730  Battlemage        Lucian  ...       Diver
# 14        Viktor  0.517730  Battlemage        Ezreal  ...    Assassin
# 15        Viktor  0.517730  Battlemage        Samira  ...  Specialist
# 16        Viktor  0.517730  Battlemage          Jhin  ...    Marksman
# 17        Viktor  0.517730  Battlemage        Ezreal  ...      Warden
# 18         Annie  0.553073       Burst          Jhin  ...      Warden
# 19        Lucian  0.421169    Marksman  Miss Fortune  ...      Warden
# 20    Cassiopeia  0.473186  Battlemage          Jhin  ...    Marksman
# 21       Orianna  0.481521       Burst          Jhin  ...       Burst
# 22         Galio  0.565594      Warden          Jhin  ...    Assassin
# 23       Orianna  0.481521       Burst        Ezreal  ...    Marksman
# 24  Twisted Fate  0.470037       Burst       Karthus  ...  Skirmisher
# 25         Galio  0.565594      Warden         Varus  ...       Burst
# 26         Annie  0.553073       Burst       Kalista  ...  Battlemage
# 27        Viktor  0.517730  Battlemage        Kai'Sa  ...    Assassin
# 28        Syndra  0.485014       Burst         Vayne  ...    Marksman
# 29  Twisted Fate  0.470037       Burst        Ezreal  ...    Assassin
# 30          Yone  0.497972  Skirmisher  Miss Fortune  ...       Burst
# 31        Xerath  0.488372   Artillery          Jhin  ...    Assassin
# 32         Sylas  0.502868       Burst          Ashe  ...       Burst
# 33         Yasuo  0.487738  Skirmisher          Ashe  ...       Burst
# 34          Ekko  0.533333    Assassin        Ezreal  ...     Catcher
# 35       Orianna  0.481521       Burst        Ezreal  ...    Marksman
# 36         Corki  0.438596    Marksman        Draven  ...       Burst
# 37         Akali  0.522516    Assassin        Ezreal  ...       Diver
# 38         Akali  0.522516    Assassin          Jinx  ...    Assassin
# 39       Taliyah  0.543799  Battlemage         Yasuo  ...    Assassin
# 40         Sylas  0.502868       Burst          Jhin  ...    Assassin
# 41         Akali  0.522516    Assassin       Morgana  ...    Assassin
# 42      Kassadin  0.496536    Assassin        Wukong  ...  Battlemage
# 43       Camille  0.524364       Diver           Zed  ...  Battlemage
# 44       LeBlanc  0.481994       Burst    Cassiopeia  ...    Assassin
# 45        Rumble  0.570707  Battlemage  Miss Fortune  ...       Diver
# 46        Gragas  0.506967    Vanguard          Jhin  ...    Vanguard
# 47          Ekko  0.533333    Assassin          Jhin  ...    Marksman
# 48        Xerath  0.488372   Artillery          Jhin  ...  Battlemage
# 49           Zoe  0.538071       Burst        Kai'Sa  ...  Battlemage
#
#             RAdc    RAdcWr    RAdctags       RSup    RSupWr    RSuptags  \
# 0         Kai'Sa  0.503883    Marksman      Karma  0.492260   Enchanter
# 1   Miss Fortune  0.504505    Marksman    Vel'Koz  0.440678   Artillery
# 2       Aphelios  0.470158    Marksman     Maokai  0.527418    Vanguard
# 3          Sivir  0.393443    Marksman       Pyke  0.492582    Assassin
# 4        Orianna  0.465315       Burst   Pantheon  0.473513       Diver
# 5        Caitlyn  0.468451    Marksman       Sett  0.424386  Juggernaut
# 6         Kai'Sa  0.503883    Marksman     Maokai  0.527418    Vanguard
# 7         Samira  0.476318    Marksman     Thresh  0.516721     Catcher
# 8         Lucian  0.497414    Marksman       Lulu  0.502555   Enchanter
# 9         Kai'Sa  0.503883    Marksman      Taric  0.520930      Warden
# 10        Kai'Sa  0.503883    Marksman       Sett  0.424386  Juggernaut
# 11        Ezreal  0.457083    Marksman    Alistar  0.509198    Vanguard
# 12        Lucian  0.497414    Marksman    Alistar  0.509198    Vanguard
# 13       Kalista  0.507772    Marksman     Zilean  0.470588  Specialist
# 14          Ashe  0.490047    Marksman     Maokai  0.527418    Vanguard
# 15        Kennen  0.519031  Specialist   Pantheon  0.473513       Diver
# 16        Kai'Sa  0.503883    Marksman       Lulu  0.502555   Enchanter
# 17        Samira  0.476318    Marksman      Rakan  0.484816     Catcher
# 18        Kai'Sa  0.503883    Marksman    Alistar  0.509198    Vanguard
# 19        Kai'Sa  0.503883    Marksman   Pantheon  0.473513       Diver
# 20        Kai'Sa  0.503883    Marksman       Bard  0.518556     Catcher
# 21          Ashe  0.490047    Marksman       Lulu  0.502555   Enchanter
# 22          Ashe  0.490047    Marksman       Lulu  0.502555   Enchanter
# 23        Kai'Sa  0.503883    Marksman     Thresh  0.516721     Catcher
# 24     Seraphine  0.496782   Enchanter       Sona  0.497207   Enchanter
# 25  Miss Fortune  0.504505    Marksman  Seraphine  0.487002   Enchanter
# 26        Kai'Sa  0.503883    Marksman      Janna  0.496114   Enchanter
# 27          Jhin  0.499863    Marksman       Pyke  0.492582    Assassin
# 28       Skarner  0.533898       Diver      Swain  0.491935  Battlemage
# 29        Twitch  0.523605    Marksman   Pantheon  0.473513       Diver
# 30          Jhin  0.499863    Marksman     Soraka  0.465217   Enchanter
# 31  Miss Fortune  0.504505    Marksman  Seraphine  0.487002   Enchanter
# 32        Ezreal  0.457083    Marksman     Maokai  0.527418    Vanguard
# 33         Vayne  0.515358    Marksman       Lulu  0.502555   Enchanter
# 34          Jhin  0.499863    Marksman      Taric  0.520930      Warden
# 35         Senna  0.512255    Marksman   Pantheon  0.473513       Diver
# 36          Ashe  0.490047    Marksman   Pantheon  0.473513       Diver
# 37       Caitlyn  0.468451    Marksman   Pantheon  0.473513       Diver
# 38        Veigar  0.459459       Burst      Karma  0.492260   Enchanter
# 39          Jhin  0.499863    Marksman   Pantheon  0.473513       Diver
# 40        Kai'Sa  0.503883    Marksman      Leona  0.487280    Vanguard
# 41          Ashe  0.490047    Marksman     Thresh  0.516721     Catcher
# 42          Ashe  0.490047    Marksman      Galio  0.559184      Warden
# 43        Ezreal  0.457083    Marksman      Yuumi  0.501908   Enchanter
# 44         Senna  0.512255    Marksman    Morgana  0.505330     Catcher
# 45          Jhin  0.499863    Marksman       Rell  0.514286    Vanguard
# 46        Samira  0.476318    Marksman   Nautilus  0.504491    Vanguard
# 47  Miss Fortune  0.504505    Marksman       Lulu  0.502555   Enchanter
# 48          Ashe  0.490047    Marksman      Leona  0.487280    Vanguard
# 49        Samira  0.476318    Marksman       Sett  0.424386  Juggernaut
#
#    Winner BSyn  RSyn
# 0       1  136   282
# 1       0  496    66
# 2       0  236    16
# 3       1   60   104
# 4       1  -32   -32
# 5       0  230  -154
# 6       1  102   312
# 7       1  -60   118
# 8       1   28  -162
# 9       0  118    12
# 10      0 -238   206
# 11      1   16  -106
# 12      0   16  -190
# 13      1 -394    32
# 14      0  -86    88
# 15      0   44   -10
# 16      1  220  -332
# 17      0 -122   174
# 18      1  230   394
# 19      1 -302   286
# 20      0   28  -290
# 21      1 -156   -62
# 22      1  404    42
# 23      0 -272   178
# 24      0   18    14
# 25      1   98    48
# 26      0  100    88
# 27      0  180   128
# 28      0   56    20
# 29      0 -174   -34
# 30      1  -48    38
# 31      0  100   -48
# 32      1   64  -180
# 33      0  -12    -2
# 34      0 -132    36
# 35      0 -206  -188
# 36      1   14   130
# 37      1 -166    24
# 38      0   26   -22
# 39      1   12   258
# 40      1  104    14
# 41      0  -94   208
# 42      0   44   100
# 43      0   14  -108
# 44      1  -24   -80
# 45      0   50   -70
# 46      0 -126    58
# 47      0  182    50
# 48      0  -26   -90
# 49      0  276  -180
#
# [50 rows x 33 columns]

# %%
df.head()
# Out:
#       BTop    BTopWr    BToptags     BJng    BJngWr    BJngtags    BMid  \
# 0  Camille  0.524364       Diver   Gragas  0.506967    Vanguard    Yone
# 1  Camille  0.524364       Diver  Nidalee  0.504318  Specialist   Galio
# 2   Irelia  0.513399       Diver     Ekko  0.486450    Assassin   Annie
# 3   Graves  0.511305  Specialist  Kindred  0.505097    Marksman   Sylas
# 4  Camille  0.524364       Diver  Lee Sin  0.509764       Diver  Lucian
#
#      BMidWr    BMidtags    BAdc  ...    RMidtags          RAdc    RAdcWr  \
# 0  0.497972  Skirmisher    Jhin  ...       Burst        Kai'Sa  0.503883
# 1  0.565594      Warden    Jhin  ...   Artillery  Miss Fortune  0.504505
# 2  0.553073       Burst  Kai'Sa  ...       Burst      Aphelios  0.470158
# 3  0.502868       Burst   Vayne  ...    Assassin         Sivir  0.393443
# 4  0.421169    Marksman  Kai'Sa  ...  Skirmisher       Orianna  0.465315
#
#    RAdctags      RSup    RSupWr   RSuptags Winner BSyn  RSyn
# 0  Marksman     Karma  0.492260  Enchanter      1  136   282
# 1  Marksman   Vel'Koz  0.440678  Artillery      0  496    66
# 2  Marksman    Maokai  0.527418   Vanguard      0  236    16
# 3  Marksman      Pyke  0.492582   Assassin      1   60   104
# 4     Burst  Pantheon  0.473513      Diver      1  -32   -32
#
# [5 rows x 33 columns]

# %%
df.drop(['BTop', 'BJng', 'BMid', 'BAdc', 'BSup', 'RTop', 'RJng', 'RMid', 'RAdc',
       'RSup'],axis=1,inplace=True)

# %%
df.head()
# Out:
#      BTopWr    BToptags    BJngWr    BJngtags    BMidWr    BMidtags    BAdcWr  \
# 0  0.524364       Diver  0.506967    Vanguard  0.497972  Skirmisher  0.523989
# 1  0.524364       Diver  0.504318  Specialist  0.565594      Warden  0.523989
# 2  0.513399       Diver  0.486450    Assassin  0.553073       Burst  0.525246
# 3  0.511305  Specialist  0.505097    Marksman  0.502868       Burst  0.524169
# 4  0.524364       Diver  0.509764       Diver  0.421169    Marksman  0.525246
#
#    BAdctags    BSupWr    BSuptags  ...    RJngtags    RMidWr    RMidtags  \
# 0  Marksman  0.438144       Burst  ...  Specialist  0.491465       Burst
# 1  Marksman  0.491429  Battlemage  ...       Diver  0.559211   Artillery
# 2  Marksman  0.524819     Catcher  ...       Diver  0.465315       Burst
# 3  Marksman  0.534702     Catcher  ...  Specialist  0.508434    Assassin
# 4  Marksman  0.516461    Vanguard  ...  Specialist  0.445918  Skirmisher
#
#      RAdcWr  RAdctags    RSupWr   RSuptags Winner  BSyn RSyn
# 0  0.503883  Marksman  0.492260  Enchanter      1   136  282
# 1  0.504505  Marksman  0.440678  Artillery      0   496   66
# 2  0.470158  Marksman  0.527418   Vanguard      0   236   16
# 3  0.393443  Marksman  0.492582   Assassin      1    60  104
# 4  0.465315     Burst  0.473513      Diver      1   -32  -32
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['BTopWr', 'BToptags', 'BJngWr', 'BJngtags', 'BMidWr', 'BMidtags',
#        'BAdcWr', 'BAdctags', 'BSupWr', 'BSuptags', 'RTopWr', 'RToptags',
#        'RJngWr', 'RJngtags', 'RMidWr', 'RMidtags', 'RAdcWr', 'RAdctags',
#        'RSupWr', 'RSuptags', 'Winner', 'BSyn', 'RSyn'],
#       dtype='object')

# %%
taglist = list(df['BToptags'].unique())

# %%
taglist
# Out:
# ['Diver',
#  'Specialist',
#  'Battlemage',
#  'Juggernaut',
#  'Skirmisher',
#  'Burst',
#  'Warden',
#  'Enchanter',
#  'Assassin',
#  'Vanguard',
#  'Artillery',
#  'Marksman',
#  'Catcher']

# %%
len(taglist)
# Out:
# 13

# %%
taglistencode = np.arange(0,13)

# %%
taglist2encode = zip(taglist,taglistencode)
taglist2encode = dict(taglist2encode)

# %%
taglist2encode
# Out:
# {'Diver': 0,
#  'Specialist': 1,
#  'Battlemage': 2,
#  'Juggernaut': 3,
#  'Skirmisher': 4,
#  'Burst': 5,
#  'Warden': 6,
#  'Enchanter': 7,
#  'Assassin': 8,
#  'Vanguard': 9,
#  'Artillery': 10,
#  'Marksman': 11,
#  'Catcher': 12}

# %%
tagcols = ['BToptags','BJngtags','BMidtags','BAdctags','BSuptags','RToptags','RJngtags','RMidtags','RAdctags','RSuptags']

# %%
for j in tagcols:
    df[j].replace(taglist2encode,inplace=True)

# %%
df
# Out:
#          BTopWr  BToptags    BJngWr  BJngtags    BMidWr  BMidtags    BAdcWr  \
# 0      0.524364         0  0.506967         9  0.497972         4  0.523989
# 1      0.524364         0  0.504318         1  0.565594         6  0.523989
# 2      0.513399         0  0.486450         8  0.553073         5  0.525246
# 3      0.511305         1  0.505097        11  0.502868         5  0.524169
# 4      0.524364         0  0.509764         0  0.421169        11  0.525246
# ...         ...       ...       ...       ...       ...       ...       ...
# 19674  0.517039        10  0.511305         1  0.517730         2  0.532787
# 19675  0.471641        11  0.504717         4  0.533333         8  0.524169
# 19676  0.493113        11  0.511305         1  0.521495         0  0.666667
# 19677  0.470149         2  0.507246         3  0.470037         5  0.498615
# 19678  0.524364         0  0.509764         0  0.502868         5  0.472814
#
#        BAdctags    BSupWr  BSuptags  ...  RJngtags    RMidWr  RMidtags  \
# 0            11  0.438144         5  ...         1  0.491465         5
# 1            11  0.491429         2  ...         0  0.559211        10
# 2            11  0.524819        12  ...         0  0.465315         5
# 3            11  0.534702        12  ...         1  0.508434         8
# 4            11  0.516461         9  ...         1  0.445918         4
# ...         ...       ...       ...  ...       ...       ...       ...
# 19674         2  0.533061         9  ...         4  0.551313         6
# 19675        11  0.529592         9  ...         3  0.532787         1
# 19676        10  0.516461         9  ...         4  0.467672        11
# 19677        11  0.533061         9  ...         1  0.506708         2
# 19678        11  0.461538         9  ...        11  0.551313         6
#
#          RAdcWr  RAdctags    RSupWr  RSuptags  Winner  BSyn  RSyn
# 0      0.503883        11  0.492260         7       1   136   282
# 1      0.504505        11  0.440678        10       0   496    66
# 2      0.470158        11  0.527418         9       0   236    16
# 3      0.393443        11  0.492582         8       1    60   104
# 4      0.465315         5  0.473513         0       1   -32   -32
# ...         ...       ...       ...       ...     ...   ...   ...
# 19674  0.457083        11  0.487002         7       1   168   182
# 19675  0.476318        11  0.509198         9       1  -218    26
# 19676  0.457083        11  0.479401         6       0    62  -564
# 19677  0.497414        11  0.516721        12       0   -86   190
# 19678  0.503883        11  0.484816        12       1  -234   182
#
# [19679 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['BTopWr', 'BToptags', 'BJngWr', 'BJngtags', 'BMidWr', 'BMidtags',
#        'BAdcWr', 'BAdctags', 'BSupWr', 'BSuptags', 'RTopWr', 'RToptags',
#        'RJngWr', 'RJngtags', 'RMidWr', 'RMidtags', 'RAdcWr', 'RAdctags',
#        'RSupWr', 'RSuptags', 'Winner', 'BSyn', 'RSyn'],
#       dtype='object')

# %% [markdown]
# ### Lets perform Decision Trees and Random Forests

# %%
X = df.drop('Winner',axis=1)
y = df['Winner']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
predict_dtc = dtc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print (confusion_matrix(y_test,predict_dtc))
print('\n')
print(classification_report(y_test,predict_dtc))
# Out:
# [[1622 1333]
#  [1367 1582]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.55      0.55      2955
#            1       0.54      0.54      0.54      2949
#
#     accuracy                           0.54      5904
#    macro avg       0.54      0.54      0.54      5904
# weighted avg       0.54      0.54      0.54      5904

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predict_rfc = rfc.predict(X_test)

# %%
print (confusion_matrix(y_test,predict_rfc))
print('\n')
print(classification_report(y_test,predict_rfc))
# Out:
# [[1883 1072]
#  [1197 1752]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.62      2955
#            1       0.62      0.59      0.61      2949
#
#     accuracy                           0.62      5904
#    macro avg       0.62      0.62      0.62      5904
# weighted avg       0.62      0.62      0.62      5904
